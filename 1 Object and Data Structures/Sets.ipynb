# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.add(1)

# %%
s
# Out:
# {1, 2}

# %%
l = [1, 1, 2, 2, 3, 3, 3, 4, 5, 6]

# %%
s = set(l)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.pop()
# Out:
# 1

# %%
s.pop()
# Out:
# 2
